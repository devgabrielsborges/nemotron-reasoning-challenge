# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("../data/raw/train.csv")

# %%
train.sample(10)
# Out:
#             id                                             prompt  \
# 7252  c2dacc5b  In Alice's Wonderland, a secret bit manipulati...
# 8020  d777480b  In Alice's Wonderland, numbers are secretly co...
# 5833  9d68ef62  In Alice's Wonderland, a secret set of transfo...
# 1313  231a83b6  In Alice's Wonderland, secret encryption rules...
# 6768  b5e1e604  In Alice's Wonderland, a secret set of transfo...
# 7412  c708be9a  In Alice's Wonderland, the gravitational const...
# 3357  59bee375  In Alice's Wonderland, a secret bit manipulati...
# 7093  be77b031  In Alice's Wonderland, secret encryption rules...
# 6273  a87bbb0b  In Alice's Wonderland, a secret unit conversio...
# 9005  f2ec1685  In Alice's Wonderland, a secret bit manipulati...
#
#                          answer
# 7252                   10000101
# 8020                      LXXIV
# 5833                        83(
# 1313  queen watches under ocean
# 6768                        211
# 7412                      19.04
# ...

# %%
train.info()
train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9500 entries, 0 to 9499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      9500 non-null   object
#  1   prompt  9500 non-null   object
#  2   answer  9500 non-null   object
# dtypes: object(3)
# memory usage: 222.8+ KB
#               id                                             prompt    answer
# count       9500                                               9500      9500
# unique      9500                                               9500      5921
# top     00066667  In Alice's Wonderland, a secret bit manipulati...  00000000
# freq           1                                                  1       103

# %%
train.isna().sum()
# Out:
# id        0
# prompt    0
# answer    0
# dtype: int64

# %%
prompt_length = train.prompt.map(len)
prompt_length
# Out:
# 0       468
# 1       489
# 2       458
# 3       215
# 4       400
#        ...
# 9495    468
# 9496    245
# 9497    458
# 9498    416
# 9499    349
# Name: prompt, Length: 9500, dtype: int64

# %%
prompt_length.median()
# Out:
# 281.0

# %%
prompt_length.mode()
# Out:
# 0    468
# 1    489
# Name: prompt, dtype: int64

# %%
import seaborn as sns

sns.displot(data=prompt_length)
